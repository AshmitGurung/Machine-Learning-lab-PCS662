# %% [markdown]
# <a href="https://colab.research.google.com/github/AshmitGurung/Machine-Learning-lab-PCS662/blob/main/week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

x=np.array([5,15,25,35,45,55]).reshape((-1,1))
y=np.array([5,20,14,32,22,38])

model=LinearRegression()
model.fit(x,y)

y_pred=model.predict(x)

plt.scatter(x,y,color="red", label="actual data")
plt.plot(x,y_pred,color="green",label="Regression line")

plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("XY Graph")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

x=np.array([5,15,25,35,45,55]).reshape((-1,1))
y=np.array([5,20,14,32,22,38])
z=[]
for i in range(len(x)):
  z.append(x[i]-y[i])

model=LinearRegression()
model.fit(x,y)

y_pred=model.predict(x)

plt.scatter(x,y,color="red", label="actual data")
plt.plot(x,z,color="green",label="Regression line")

plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("XY Graph")

plt.show()
